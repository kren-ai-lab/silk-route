# %% [markdown]
# # Protein Query-First Workflow
#
# `query_first` runs one executable `query.value` string for a selected modality. This notebook uses the minimal protein workflow descriptor.
#
# Running the workflow calls live APIs and requires internet access. If the API or network is unavailable, the command may fail; the notebook handles that case gracefully.

# %%
import json
import subprocess
import sys
from pathlib import Path

repo_root = Path.cwd().parent.parent
config_path = repo_root / "examples" / "workflows" / "protein_query_first_minimal.yml"
output_dir = repo_root / "examples" / "results" / "protein_query_first_minimal"

print(config_path)
# Out:
# c:\Users\Rosem\Documents\PythonProjects\BioSeqDownloader\examples\workflows\protein_query_first_minimal.yml

# %% [markdown]
# ## Run the workflow
#
# The command below uses the module form so it runs against the current Python environment.

# %%
command = [
    sys.executable,
    "-m",
    "bioseq_dl.cli.main",
    "workflow",
    "run",
    "--config",
    str(config_path),
]

result = subprocess.run(command, cwd=repo_root, capture_output=True, text=True, check=False)
print(result.stdout)

if result.returncode != 0:
    print("Workflow execution did not complete. This can happen when internet access or an API service is unavailable.")
    print(result.stderr)
else:
    print("Workflow completed.")
# Out:
# 2026-06-18 15:38:40 | INFO     | bioseq_dl.core.workflow.main | Pipeline: fetching UniProt for query=gene:TP53 AND reviewed:true AND organism_id:9606 fields= sort=accession asc include_isoform=False
# 2026-06-18 15:38:40 | INFO     | bioseq_dl.interfaces.uniprot | UniProt stream request started (path=/uniprotkb/stream)
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.interfaces.uniprot | UniProt stream response received (status=200 elapsed=2.19s)
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.core.workflow.main | Pipeline: UniProt fetch completed (status=200 elapsed=2.193598508834839 size_bytes=869349 results=1)
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.core.workflow.main | Pipeline: parsing UniProt results format=dataframe
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.core.workflow.main | Pipeline: UniProt parse completed (elapsed=0.02s parsed=1 output_type=DataFrame)
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.core.workflow.main | Pipeline: enrichment skipped (enrich=False)
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.cli.workflows | Exporting workflow results to examples\results\protein_query_first_minimal
# 2026-06-18 15:38:43 | INFO     | bioseq_dl.cli.workflows | Workflow export completed
# Workflow completed. Results saved to 'examples\results\protein_query_first_minimal'
#
# Workflow completed.

# %% [markdown]
# ## Inspect output files
#
# When execution succeeds, the workflow writes result files plus metadata and a run summary under the configured output directory.

# %%
if output_dir.exists():
    print("Output files:")
    for path in sorted(output_dir.iterdir()):
        print("-", path.relative_to(repo_root))

    metadata_path = output_dir / "metadata.json"
    if metadata_path.exists():
        metadata = json.loads(metadata_path.read_text(encoding="utf-8"))
        print("Metadata keys:", sorted(metadata))
else:
    print("No output directory exists yet. Run the workflow when internet access is available.")
# Out:
# Output files:
# - examples\results\protein_query_first_minimal\metadata.json
# - examples\results\protein_query_first_minimal\run_summary.yml
# - examples\results\protein_query_first_minimal\uniprot_results.csv
# Metadata keys: ['execution', 'normalized_descriptor', 'normalized_workflow_values', 'original_descriptor', 'output_files', 'reporting', 'tool', 'workflow_metadata']
